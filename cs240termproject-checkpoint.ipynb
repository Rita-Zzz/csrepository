# %%
import pandas as pd
import thinkstats2
import thinkplot
import numpy as np
# %matplotlib inline

# %%
manager = pd.read_csv("Managers.csv")

# %%
manager
# Out:
#        playerID  yearID teamID lgID  inseason    G    W    L  rank plyrMgr
# 0     wrighha01    1871    BS1  NaN         1   31   20   10   3.0       Y
# 1      woodji01    1871    CH1  NaN         1   28   19    9   2.0       Y
# 2     paborch01    1871    CL1  NaN         1   29   10   19   8.0       Y
# 3     lennobi01    1871    FW1  NaN         1   14    5    9   8.0       Y
# 4     deaneha01    1871    FW1  NaN         2    5    2    3   8.0       Y
# 5     fergubo01    1871    NY2  NaN         1   33   16   17   5.0       Y
# 6     mcbridi01    1871    PH1  NaN         1   28   21    7   1.0       Y
# 7     hastisc01    1871    RC1  NaN         1   25    4   21   9.0       Y
# 8      pikeli01    1871    TRO  NaN         1    4    1    3   6.0       Y
# 9     cravebi01    1871    TRO  NaN         2   25   12   12   6.0       Y
# 10    youngni99    1871    WS3  NaN         1   32   15   15   4.0       N
# ...

# %%
manager.describe()
# Out:
#             yearID     inseason            G            W            L  \
# count  3436.000000  3436.000000  3436.000000  3436.000000  3436.000000
# mean   1954.223516     1.233120   124.168510    61.729627    61.738068
# std      42.078606     0.596025    50.414981    28.746768    26.417168
# min    1871.000000     1.000000     1.000000     0.000000     0.000000
# 25%    1918.000000     1.000000    91.000000    42.000000    46.000000
# 50%    1962.000000     1.000000   154.000000    70.000000    68.000000
# 75%    1991.000000     1.000000   162.000000    84.000000    81.000000
# max    2016.000000     9.000000   165.000000   116.000000   120.000000
#
#               rank
# count  3435.000000
# mean      4.339738
# std       2.396520
# min       1.000000
# 25%       2.000000
# 50%       4.000000
# 75%       6.000000
# max      12.000000

# %%
hist = thinkstats2.Hist(manager.G, label='G')
hist
# Out:
# Hist({1: 37, 2: 20, 3: 9, 4: 11, 5: 8, 6: 11, 7: 7, 8: 11, 9: 7, 10: 11, 11: 13, 12: 7, 13: 10, 14: 10, 15: 4, 16: 12, 17: 15, 18: 7, 19: 7, 20: 7, 21: 1, 22: 8, 23: 11, 24: 7, 25: 15, 26: 5, 27: 9, 28: 10, 29: 10, 30: 8, 31: 9, 32: 7, 33: 7, 34: 7, 35: 11, 36: 8, 37: 12, 38: 10, 39: 11, 40: 16, 41: 10, 42: 9, 43: 7, 44: 7, 45: 3, 46: 13, 47: 9, 48: 3, 49: 5, 50: 13, 51: 13, 52: 4, 53: 11, 54: 8, 55: 6, 56: 9, 57: 10, 58: 11, 59: 3, 60: 14, 61: 11, 62: 9, 63: 14, 64: 5, 65: 10, 66: 7, 67: 6, 68: 5, 69: 9, 70: 13, 71: 6, 72: 4, 73: 10, 74: 12, 75: 12, 76: 9, 77: 6, 78: 9, 79: 15, 80: 14, 81: 9, 82: 11, 83: 11, 84: 14, 85: 11, 86: 13, 87: 6, 88: 6, 89: 2, 90: 9, 91: 8, 92: 6, 93: 6, 94: 4, 95: 8, 96: 12, 97: 3, 98: 12, 99: 7, 100: 10, 101: 3, 102: 5, 103: 6, 104: 8, 105: 10, 106: 9, 107: 5, 108: 6, 109: 10, 110: 12, 111: 11, 112: 14, 113: 17, 114: 14, 115: 18, 116: 6, 117: 5, 118: 6, 119: 2, 120: 9, 121: 8, 122: 3, 123: 3, 124: 12, 125: 11, 126: 12, 127: 7, 128: 5, 129: 6, 130: 10, 131
# ...

# %%
pmfg = thinkstats2.Pmf(manager.G)
pmfg
# Out:
# Pmf({1: 0.010768335273573923, 2: 0.0058207217694994182, 3: 0.0026193247962747381, 4: 0.0032013969732246797, 5: 0.0023282887077997671, 6: 0.0032013969732246797, 7: 0.0020372526193247961, 8: 0.0032013969732246797, 9: 0.0020372526193247961, 10: 0.0032013969732246797, 11: 0.0037834691501746217, 12: 0.0020372526193247961, 13: 0.0029103608847497091, 14: 0.0029103608847497091, 15: 0.0011641443538998836, 16: 0.0034924330616996507, 17: 0.0043655413271245632, 18: 0.0020372526193247961, 19: 0.0020372526193247961, 20: 0.0020372526193247961, 21: 0.00029103608847497089, 22: 0.0023282887077997671, 23: 0.0032013969732246797, 24: 0.0020372526193247961, 25: 0.0043655413271245632, 26: 0.0014551804423748546, 27: 0.0026193247962747381, 28: 0.0029103608847497091, 29: 0.0029103608847497091, 30: 0.0023282887077997671, 31: 0.0026193247962747381, 32: 0.0020372526193247961, 33: 0.0020372526193247961, 34: 0.0020372526193247961, 35: 0.0032013969732246797, 36: 0.0023282887077997671, 37: 0.0034924330616996507, 38:
# ...

# %%
thinkplot.Pmf(pmfw)
thinkplot.Config(xlabel='Pregnancy length (weeks)', ylabel='Pmf')

# %%
thinkplot.Pmf(pmfg)
thinkplot.Config(xlabel='Pregnancy length (weeks)', ylabel='Pmf')

# %%
cdf = thinkstats2.Cdf(manager.G)
thinkplot.Cdf(cdf)
thinkplot.Config(xlabel='games', ylabel='CDF', loc='upper left')

# %%
cdf = thinkstats2.Cdf(manager.W)
thinkplot.Cdf(cdf)
thinkplot.Config(xlabel='wins', ylabel='CDF', loc='upper left')

# %%
thinkplot.PrePlot(3)
for lam in [2.0, 1, 0.5]:
    xs, ps = thinkstats2.RenderExpoCdf(lam, manager.G.min(), manager.G.max())
    label = r'$\lambda=%g$' % lam
    thinkplot.Plot(xs, ps, label=label)
    
thinkplot.Config(title='Exponential CDF', xlabel='x', ylabel='CDF', 
                 loc='lower right')

# %%
thinkplot.PrePlot(3)
for lam in [2.0, 1, 0.5]:
    xs, ps = thinkstats2.RenderExpoCdf(lam, manager.G.min(), manager.G.max())
    label = r'$\lambda=%g$' % lam
    thinkplot.Plot(xs, ps, label=label)
    
thinkplot.Config(title='Exponential CDF', xlabel='x', ylabel='CDF', 
                 loc='lower right')

# %%
def Cov(xs, ys, meanx=None, meany=None):
    W = np.asarray(xs)
    G = np.asarray(ys)

    if meanx is None:
        meanx = np.mean(W)
    if meany is None:
        meany = np.mean(G)

    cov = np.dot(W-meanx, G-meany) / len(W)
    return cov

# %%
Cov(manager.G,manager.W)
# Out:
# 1332.0051064297629

# %%
np.corrcoef(manager.G,manager.W)
# Out:
# array([[ 1.        ,  0.91935592],
#        [ 0.91935592,  1.        ]])

# %%
class HypothesisTest(object):

    def __init__(self, data):
        self.data = data
        self.MakeModel()
        self.actual = self.TestStatistic(data)

    def PValue(self, iters=100):
        self.test_stats = [self.TestStatistic(self.RunModel()) 
                           for _ in range(iters)]

        count = sum(1 for x in self.test_stats if x >= self.actual)
        print(count)
        return count / iters

    def TestStatistic(self, data):
        raise UnimplementedMethodException()

    def MakeModel(self):
        pass

    def RunModel(self):
        raise UnimplementedMethodException()

# %%
class DiffMeansPermute(thinkstats2.HypothesisTest):

    def TestStatistic(self, data):
        group1, group2 = data
        test_stat = abs(group1.std() - group2.std())
        return test_stat

    def MakeModel(self):
        group1, group2 = self.data
        self.n, self.m = len(group1), len(group2)
        self.pool = np.hstack((group1, group2))

    def RunModel(self):
        np.random.shuffle(self.pool)
        data = self.pool[:self.n], self.pool[self.n:]
        return data

# %%
data = manager.W, manager.G
dper = DiffMeansPermute(data)
pvalue = dper.PValue()
pvalue
# Out:
# 0.0
